# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = sns.load_dataset("tips")
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# SCATTER PLOT 

sns.scatterplot(x="tip",y="total_bill",data=data)
plt.title("Scatter Plot of Revenue w.r.t Days of a week")
plt.show()

# %%
# lINE PLOT

sns.lineplot(x="size",y="total_bill",
             data=data,
             color="mediumvioletred")
plt.title("Total Bill with size")
plt.show()

# %%
# CATEGORICAL PLOTS

#BAR PLOT
sns.barplot(x="total_bill",y="sex",data=data,
            color="crimson")
plt.title("Total Bill according to sex")
plt.show()

# %%
#BAR PLOT

sns.barplot(x="day",y="total_bill",data=data)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#VIOLIN PLOT
sns.violinplot(x="day",y="total_bill",data=data)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#HISTOGRAM
sns.histplot(data['total_bill'],bins=15,kde=True) #bins = no.of bars || kde = Curve
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
#KDE PLOT
sns.kdeplot(data['total_bill'],fill=True,color="orange")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#PAIR PLOTS
sns.pairplot(data)

# %%
#HEATMAPS
corr=data[['total_bill','tip','size']].corr()
corr
sns.heatmap(corr,annot=True,cmap='rocket')
# Out:
# <Axes: >

# %%
##USING PANDAS + MATPLOTLIB + SEABORN 

import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("avengers.csv")
data.head()
plt.figure(figsize=(12, 6))
plt.title("Avengers Power Points")
sns.barplot(x="alias",y="power_lvl",data=data)
# Out:
# <Axes: title={'center': 'Avengers Power Points'}, xlabel='alias', ylabel='power_lvl'>
